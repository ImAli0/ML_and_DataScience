# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Advertising.csv')

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df['total_spent']=df['TV']+df['radio']+df['newspaper']
df
# Out:
#         TV  radio  newspaper  sales  total_spent
# 0    230.1   37.8       69.2   22.1        337.1
# 1     44.5   39.3       45.1   10.4        128.9
# 2     17.2   45.9       69.3    9.3        132.4
# 3    151.5   41.3       58.5   18.5        251.3
# 4    180.8   10.8       58.4   12.9        250.0
# ..     ...    ...        ...    ...          ...
# 195   38.2    3.7       13.8    7.6         55.7
# 196   94.2    4.9        8.1    9.7        107.2
# 197  177.0    9.3        6.4   12.8        192.7
# 198  283.6   42.0       66.2   25.5        391.8
# 199  232.1    8.6        8.7   13.4        249.4
#
# [200 rows x 5 columns]

# %%
sns.scatterplot(x='total_spent',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
sns.regplot(x=df['total_spent'],y=df['sales'])
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
X=df['total_spent']
y=df['sales']

# %%
np.polyfit(X,y,1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend=np.linspace(0,600,100)
potential_spend
# Out:
# array([  0.        ,   6.06060606,  12.12121212,  18.18181818,
#         24.24242424,  30.3030303 ,  36.36363636,  42.42424242,
#         48.48484848,  54.54545455,  60.60606061,  66.66666667,
#         72.72727273,  78.78787879,  84.84848485,  90.90909091,
#         96.96969697, 103.03030303, 109.09090909, 115.15151515,
#        121.21212121, 127.27272727, 133.33333333, 139.39393939,
#        145.45454545, 151.51515152, 157.57575758, 163.63636364,
#        169.6969697 , 175.75757576, 181.81818182, 187.87878788,
#        193.93939394, 200.        , 206.06060606, 212.12121212,
#        218.18181818, 224.24242424, 230.3030303 , 236.36363636,
#        242.42424242, 248.48484848, 254.54545455, 260.60606061,
#        266.66666667, 272.72727273, 278.78787879, 284.84848485,
#        290.90909091, 296.96969697, 303.03030303, 309.09090909,
#        315.15151515, 321.21212121, 327.27272727, 333.33333333,
#        339.39393939, 345.45454545, 351.51515152, 357.57575758,
# ...

# %%
predicted_sales=0.04868788*potential_spend+4.24302822
predicted_sales
# Out:
# array([ 4.24302822,  4.53810628,  4.83318434,  5.1282624 ,  5.42334046,
#         5.71841852,  6.01349658,  6.30857464,  6.6036527 ,  6.89873077,
#         7.19380883,  7.48888689,  7.78396495,  8.07904301,  8.37412107,
#         8.66919913,  8.96427719,  9.25935525,  9.55443331,  9.84951137,
#        10.14458943, 10.43966749, 10.73474555, 11.02982361, 11.32490167,
#        11.61997974, 11.9150578 , 12.21013586, 12.50521392, 12.80029198,
#        13.09537004, 13.3904481 , 13.68552616, 13.98060422, 14.27568228,
#        14.57076034, 14.8658384 , 15.16091646, 15.45599452, 15.75107258,
#        16.04615064, 16.3412287 , 16.63630677, 16.93138483, 17.22646289,
#        17.52154095, 17.81661901, 18.11169707, 18.40677513, 18.70185319,
#        18.99693125, 19.29200931, 19.58708737, 19.88216543, 20.17724349,
#        20.47232155, 20.76739961, 21.06247767, 21.35755574, 21.6526338 ,
#        21.94771186, 22.24278992, 22.53786798, 22.83294604, 23.1280241 ,
# ...

# %%
plt.plot(potential_spend,predicted_sales)

# %%
sns.scatterplot(x=potential_spend,y=predicted_sales)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales,c='r')

# %%
sns.scatterplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales,c='r')
sns.regplot(x=df['total_spent'],y=df['sales'])
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
spend=201
predict=0.04868788*spend+4.24302822
predict
# Out:
# 14.0292921

# %%
np.polyfit(X,y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
predicted_sales0=3.07615033e-07*potential_spend**3+-1.89392449e-04*potential_spend**2+8.20886302e-02*potential_spend+2.70495053e+00
predicted_sales0
# Out:
# array([ 2.70495053,  3.19556929,  3.6726858 ,  4.13671093,  4.58805555,
#         5.02713053,  5.45434674,  5.87011506,  6.27484636,  6.66895151,
#         7.05284138,  7.42692685,  7.79161879,  8.14732808,  8.49446557,
#         8.83344215,  9.16466869,  9.48855606,  9.80551514, 10.11595679,
#        10.42029188, 10.7189313 , 11.01228591, 11.30076659, 11.5847842 ,
#        11.86474963, 12.14107373, 12.4141674 , 12.68444148, 12.95230687,
#        13.21817443, 13.48245504, 13.74555956, 14.00789887, 14.26988385,
#        14.53192536, 14.79443427, 15.05782146, 15.32249781, 15.58887418,
#        15.85736144, 16.12837047, 16.40231215, 16.67959734, 16.96063691,
#        17.24584174, 17.5356227 , 17.83039067, 18.13055651, 18.4365311 ,
#        18.74872531, 19.06755001, 19.39341608, 19.72673438, 20.06791579,
#        20.41737119, 20.77551144, 21.14274742, 21.51948999, 21.90615004,
#        22.30313844, 22.71086605, 23.12974375, 23.56018241, 24.0025929 ,
# ...

# %%
plt.plot(potential_spend,predicted_sales0)

# %%
sns.scatterplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales0,c='r')

# %%
sns.scatterplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales0,c='r')
sns.regplot(x=df['total_spent'],y=df['sales'])
# Out:
# <AxesSubplot:xlabel='total_spent', ylabel='sales'>

# %%
sns.scatterplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales0,c='r')
sns.regplot(x=df['total_spent'],y=df['sales'])
plt.plot(potential_spend,predicted_sales,c='b')

# %%
X = df[['TV','radio','newspaper']]
y = df['sales']

# %%
np.polyfit(X,y,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-58a083dadd2c> in <module>
# ----> 1 np.polyfit(X,y,1)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     626         raise ValueError("expected deg >= 0")
#     627     if x.ndim != 1:
# --> 628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
#     630         raise TypeError("expected non-empty vector for x")
#
# TypeError: expected 1D vector for x

# %%
np.polyfit(X,y,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-6bc8ee5a8d3d> in <module>
# ----> 1 np.polyfit(X,y,3)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     626         raise ValueError("expected deg >= 0")
#     627     if x.ndim != 1:
# --> 628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
#     630         raise TypeError("expected non-empty vector for x")
#
# TypeError: expected 1D vector for x
