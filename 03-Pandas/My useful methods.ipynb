# %% [markdown]
# # Useful methods
# ### The .apply() method

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_six(num):
    return int(str(num)[-6:])

# %%
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
last_six(3560325168603410)
# Out:
# 603410

# %%
df['last_six']=df['CC Number'].apply(last_six)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six
# ...

# %% [markdown]
# # Using .apply() with more complex functions

# %%
def yelp(price):
    if price<12:
        return '$'
    elif price>=12 and price<35:
        return '$$'
    else:
        return '$$$'

# %%
df['Expensive']=df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df[df['Expensive']=='$$$']
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 112       38.07   4.00    Male     No   Sun  Dinner     3             12.69
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# ...

# %% [markdown]
# # apply with lambda

# %%
def simple(num):
    return num*2

# %%
simple
# Out:
# <function __main__.simple(num)>

# %%
lambda bill: bill*2
# Out:
# <function __main__.<lambda>(bill)>

# %%
df['total_bill'].apply(simple)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill'].apply(lambda bill: bill*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# # apply that uses multiple columns

# %%
def quality(total_bill,tip):
    if tip/total_bill>0.25:
        return 'Generous'
    else:
        return 'Other'

# %%
df['Tip Quality']=df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df[df['Tip Quality']=='Generous']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 51        10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2              7.16
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2              4.80
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4              5.79
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2              6.71
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
#
#             Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %%
df['Tip Quality']=np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %% [markdown]
# So wich one is faster?

# %%
import timeit

# %%
setup = '''
import numpy as np
import pandas as pd
df=pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill>0.25:
        return 'Generous'
    else:
        return 'Other'
'''


    
    
stmt_one = '''
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''


stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 6.466112299999963

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.7813828999999259

# %% [markdown]
# # df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number  \
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15
#
#             last_six
# count     244.000000
# mean   490924.106557
# std    287574.575569
# min      3487.000000
# 25%    252741.500000
# 50%    484377.000000
# 75%    733867.750000
# max    995267.000000

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
# last_six          244.0  4.909241e+05  2.875746e+05  3.487000e+03
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %% [markdown]
# ## df.sort_values() to sort

# %%
df.sort_values('Tip Quality')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4              5.79
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2              4.80
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 87        18.28  4.00    Male     No  Thur   Lunch     2              9.14
# 88        24.71  5.85    Male     No  Thur   Lunch     2             12.36
# 89        21.16  3.00    Male     No  Thur   Lunch     2             10.58
# 123       15.95  2.00    Male     No  Thur   Lunch     2              7.98
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
help(df.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key: 'ValueKeyFunc' = None) method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#             by : str or list of str
#                 Name or list of names to sort by.
#
#                 - if `axis` is 0 or `'index'` then `by` may contain index
#                   levels and/or column labels.
#                 - if `axis` is 1 or `'columns'` then `by` may contain column
#                   levels and/or index labels.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.sort_values(['tip','size'],0,False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
# ...

# %% [markdown]
# # df.corr() for correlation checks

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number  \
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000
# last_six           -0.047022 -0.022035 -0.045167         -0.031713   0.045446
#
#                   last_six
# total_bill       -0.047022
# tip              -0.022035
# size             -0.045167
# price_per_person -0.031713
# CC Number         0.045446
# last_six          1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# ## idxmin and idxmax

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['tip'].idxmax()
# Out:
# 170

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df['tip'].min()
# Out:
# 1.0

# %%
df['tip'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_six                      995267
# Expensive                          $
# Tip Quality                 Generous
# Name: 67, dtype: object

# %%
df.iloc[df['total_bill'].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_six                      995267
# Expensive                          $
# Tip Quality                 Generous
# Name: 67, dtype: object

# %% [markdown]
# ### value_counts

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['total_bill'].value_counts()
# Out:
# 13.42    3
# 21.01    2
# 18.29    2
# 10.07    2
# 20.69    2
#         ..
# 24.27    1
# 38.07    1
# 7.51     1
# 14.52    1
# 26.88    1
# Name: total_bill, Length: 229, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 2.50    10
# 5.00    10
#         ..
# 6.70     1
# 4.50     1
# 1.67     1
# 1.73     1
# 2.61     1
# Name: tip, Length: 123, dtype: int64

# %%
df['Expensive'].value_counts()
# Out:
# $$     188
# $       40
# $$$     16
# Name: Expensive, dtype: int64

# %% [markdown]
# ### replace

# %%
df['Tip Quality'].replace('Other','Ok')
# Out:
# 0      Ok
# 1      Ok
# 2      Ok
# 3      Ok
# 4      Ok
#        ..
# 239    Ok
# 240    Ok
# 241    Ok
# 242    Ok
# 243    Ok
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality']=df['Tip Quality'].replace('Other','Ok')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df[['Tip Quality','time']]=df[['Tip Quality','time']].replace(['Ok','Lunch','Dinner'],['Other','L','D'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun    D     2              8.49
# 1         10.34  1.66    Male     No   Sun    D     3              3.45
# 2         21.01  3.50    Male     No   Sun    D     3              7.00
# 3         23.68  3.31    Male     No   Sun    D     2             11.84
# 4         24.59  3.61  Female     No   Sun    D     4              6.15
# ..          ...   ...     ...    ...   ...  ...   ...               ...
# 239       29.03  5.92    Male     No   Sat    D     3              9.68
# 240       27.18  2.00  Female    Yes   Sat    D     2             13.59
# 241       22.67  2.00    Male    Yes   Sat    D     2             11.34
# 242       17.82  1.75    Male     No   Sat    D     2              8.91
# 243       18.78  3.00  Female     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %%
df[['sex','smoker','day','time']]=df[['sex','smoker','day','time']].replace(['Female', 'Male', 'Yes', 'No', 'Thur', 'Fri', 'Sat', 'Sun', 'D', 'L'],['F', 'M', 'Y', 'N', 'THU', 'FRI', 'SAT', 'SUN', 'Dinner', 'Lunch'])

# %%
df
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01   F      N  SUN  Dinner     2              8.49
# 1         10.34  1.66   M      N  SUN  Dinner     3              3.45
# 2         21.01  3.50   M      N  SUN  Dinner     3              7.00
# 3         23.68  3.31   M      N  SUN  Dinner     2             11.84
# 4         24.59  3.61   F      N  SUN  Dinner     4              6.15
# ..          ...   ...  ..    ...  ...     ...   ...               ...
# 239       29.03  5.92   M      N  SAT  Dinner     3              9.68
# 240       27.18  2.00   F      Y  SAT  Dinner     2             13.59
# 241       22.67  2.00   M      Y  SAT  Dinner     2             11.34
# 242       17.82  1.75   M      N  SAT  Dinner     2              8.91
# 243       18.78  3.00   F      N  THU  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %% [markdown]
# ### unique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['day'].unique()
# Out:
# array(['SUN', 'SAT', 'THU', 'FRI'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
df
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01   F      N  SUN  Dinner     2              8.49
# 1         10.34  1.66   M      N  SUN  Dinner     3              3.45
# 2         21.01  3.50   M      N  SUN  Dinner     3              7.00
# 3         23.68  3.31   M      N  SUN  Dinner     2             11.84
# 4         24.59  3.61   F      N  SUN  Dinner     4              6.15
# ..          ...   ...  ..    ...  ...     ...   ...               ...
# 239       29.03  5.92   M      N  SAT  Dinner     3              9.68
# 240       27.18  2.00   F      Y  SAT  Dinner     2             13.59
# 241       22.67  2.00   M      Y  SAT  Dinner     2             11.34
# 242       17.82  1.75   M      N  SAT  Dinner     2              8.91
# 243       18.78  3.00   F      N  THU  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %% [markdown]
# ### map

# %%
df
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01   F      N  SUN  Dinner     2              8.49
# 1         10.34  1.66   M      N  SUN  Dinner     3              3.45
# 2         21.01  3.50   M      N  SUN  Dinner     3              7.00
# 3         23.68  3.31   M      N  SUN  Dinner     2             11.84
# 4         24.59  3.61   F      N  SUN  Dinner     4              6.15
# ..          ...   ...  ..    ...  ...     ...   ...               ...
# 239       29.03  5.92   M      N  SAT  Dinner     3              9.68
# 240       27.18  2.00   F      Y  SAT  Dinner     2             13.59
# 241       22.67  2.00   M      Y  SAT  Dinner     2             11.34
# 242       17.82  1.75   M      N  SAT  Dinner     2              8.91
# 243       18.78  3.00   F      N  THU  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %%
df['sex']=df['sex'].map()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-d64e846b2a57> in <module>
# ----> 1 df['sex']=df['sex'].map()
#
# TypeError: map() missing 1 required positional argument: 'arg'

# %%
df
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01   F      N  SUN  Dinner     2              8.49
# 1         10.34  1.66   M      N  SUN  Dinner     3              3.45
# 2         21.01  3.50   M      N  SUN  Dinner     3              7.00
# 3         23.68  3.31   M      N  SUN  Dinner     2             11.84
# 4         24.59  3.61   F      N  SUN  Dinner     4              6.15
# ..          ...   ...  ..    ...  ...     ...   ...               ...
# 239       29.03  5.92   M      N  SAT  Dinner     3              9.68
# 240       27.18  2.00   F      Y  SAT  Dinner     2             13.59
# 241       22.67  2.00   M      Y  SAT  Dinner     2             11.34
# 242       17.82  1.75   M      N  SAT  Dinner     2              8.91
# 243       18.78  3.00   F      N  THU  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  last_six Expensive  \
# ...

# %%
df=pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time']=df['time'].map(my_map)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun    D     2              8.49
# 1         10.34  1.66    Male     No   Sun    D     3              3.45
# 2         21.01  3.50    Male     No   Sun    D     3              7.00
# 3         23.68  3.31    Male     No   Sun    D     2             11.84
# 4         24.59  3.61  Female     No   Sun    D     4              6.15
# ..          ...   ...     ...    ...   ...  ...   ...               ...
# 239       29.03  5.92    Male     No   Sat    D     3              9.68
# 240       27.18  2.00  Female    Yes   Sat    D     2             13.59
# 241       22.67  2.00    Male    Yes   Sat    D     2             11.34
# 242       17.82  1.75    Male     No   Sat    D     2              8.91
# 243       18.78  3.00  Female     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
mymap={'Female':'F','Male':'M'}

# %%
df['sex']=df['sex'].map(mymap)

# %%
df
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 1         10.34  1.66   M     No   Sun    D     3              3.45
# 2         21.01  3.50   M     No   Sun    D     3              7.00
# 3         23.68  3.31   M     No   Sun    D     2             11.84
# 4         24.59  3.61   F     No   Sun    D     4              6.15
# ..          ...   ...  ..    ...   ...  ...   ...               ...
# 239       29.03  5.92   M     No   Sat    D     3              9.68
# 240       27.18  2.00   F    Yes   Sat    D     2             13.59
# 241       22.67  2.00   M    Yes   Sat    D     2             11.34
# 242       17.82  1.75   M     No   Sat    D     2              8.91
# 243       18.78  3.00   F     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
df
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 1         10.34  1.66   M     No   Sun    D     3              3.45
# 2         21.01  3.50   M     No   Sun    D     3              7.00
# 3         23.68  3.31   M     No   Sun    D     2             11.84
# 4         24.59  3.61   F     No   Sun    D     4              6.15
# ..          ...   ...  ..    ...   ...  ...   ...               ...
# 239       29.03  5.92   M     No   Sat    D     3              9.68
# 240       27.18  2.00   F    Yes   Sat    D     2             13.59
# 241       22.67  2.00   M    Yes   Sat    D     2             11.34
# 242       17.82  1.75   M     No   Sat    D     2              8.91
# 243       18.78  3.00   F     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %% [markdown]
# ## Duplicates
# ### .duplicated() and drop_duplicates()

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df=pd.DataFrame([1,2,2,2],['a','b','c','d'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df[simple_df.duplicated()]
# Out:
#    0
# c  2
# d  2

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
df
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 1         10.34  1.66   M     No   Sun    D     3              3.45
# 2         21.01  3.50   M     No   Sun    D     3              7.00
# 3         23.68  3.31   M     No   Sun    D     2             11.84
# 4         24.59  3.61   F     No   Sun    D     4              6.15
# ..          ...   ...  ..    ...   ...  ...   ...               ...
# 239       29.03  5.92   M     No   Sat    D     3              9.68
# 240       27.18  2.00   F    Yes   Sat    D     2             13.59
# 241       22.67  2.00   M    Yes   Sat    D     2             11.34
# 242       17.82  1.75   M     No   Sat    D     2              8.91
# 243       18.78  3.00   F     No  Thur    D     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %% [markdown]
# ## between

# %%
df['total_bill'].between(20,30,True)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(25,30,True)]
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 5         25.29  4.71   M     No   Sun    D     4              6.32
# 7         26.88  3.12   M     No   Sun    D     4              6.72
# 48        28.55  2.05   M     No   Sun    D     3              9.52
# 54        25.56  4.34   M     No   Sun    D     4              6.39
# 57        26.41  1.50   F     No   Sat    D     2             13.20
# 72        26.86  3.14   F    Yes   Sat    D     2             13.43
# 73        25.28  5.00   F    Yes   Sat    D     2             12.64
# 77        27.20  4.00   M     No  Thur    L     4              6.80
# 90        28.97  3.00   M    Yes   Fri    D     2             14.48
# 96        27.28  4.00   M    Yes   Fri    D     2             13.64
# 107       25.21  4.29   M    Yes   Sat    D     2             12.60
# 114       25.71  4.00   F     No   Sun    D     3              8.57
# 116       29.93  5.07   M     No   Sun    D     4              7.48
# ...

# %% [markdown]
# ## sample

# %%
df.sample(7)
# Out:
#      total_bill   tip sex smoker  day time  size  price_per_person  \
# 57        26.41  1.50   F     No  Sat    D     2             13.20
# 234       15.53  3.00   M    Yes  Sat    D     2              7.76
# 156       48.17  5.00   M     No  Sun    D     6              8.03
# 176       17.89  2.00   M    Yes  Sun    D     2              8.94
# 69        15.01  2.09   M    Yes  Sat    D     2              7.50
# 65        20.08  3.15   M     No  Sat    D     3              6.69
# 70        12.02  1.97   M     No  Sat    D     2              6.01
#
#          Payer Name         CC Number Payment ID
# 57     Melody Simon  4745394421258160    Sat8980
# 234   Tracy Douglas  4097938155941930    Sat7220
# 156   Ryan Gonzales  3523151482063321    Sun7518
# 176  Walter Simmons  6011481578696110    Sun5961
# 69        Adam Hall  4700924377057571     Sat855
# 65     Justin Dixon   180021262464926    Sat6840
# 70        Max Brown   213139760497718    Sat2100

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 58        11.24  1.76   M    Yes   Sat    D     2              5.62
# 217       11.59  1.50   M    Yes   Sat    D     2              5.80
# 77        27.20  4.00   M     No  Thur    L     4              6.80
# 128       11.38  2.00   F     No  Thur    L     2              5.69
# 223       15.98  3.00   F     No   Fri    L     3              5.33
# 187       30.46  2.00   M    Yes   Sun    D     5              6.09
# 218        7.74  1.44   M    Yes   Sat    D     2              3.87
# 8         15.04  1.96   M     No   Sun    D     2              7.52
# 200       18.71  4.00   M    Yes  Thur    L     3              6.24
# 197       43.11  5.00   F    Yes  Thur    L     4             10.78
# 70        12.02  1.97   M     No   Sat    D     2              6.01
# 219       30.14  3.09   F    Yes   Sat    D     4              7.54
# 43         9.68  1.32   M     No   Sun    D     2              4.84
# ...

# %% [markdown]
# # nlargest and nsmallest

# %%
df.nlargest(10,'total_bill')
# Out:
#      total_bill    tip sex smoker   day time  size  price_per_person  \
# 170       50.81  10.00   M    Yes   Sat    D     3             16.94
# 212       48.33   9.00   M     No   Sat    D     4             12.08
# 59        48.27   6.73   M     No   Sat    D     4             12.07
# 156       48.17   5.00   M     No   Sun    D     6              8.03
# 182       45.35   3.50   M    Yes   Sun    D     3             15.12
# 102       44.30   2.50   F    Yes   Sat    D     3             14.77
# 197       43.11   5.00   F    Yes  Thur    L     4             10.78
# 142       41.19   5.00   M     No  Thur    L     5              8.24
# 184       40.55   3.00   M    Yes   Sun    D     2             20.27
# 95        40.17   4.73   M    Yes   Fri    D     4             10.04
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df.sort_values(['total_bill'],ascending=True)
# Out:
#      total_bill    tip sex smoker   day time  size  price_per_person  \
# 67         3.07   1.00   F    Yes   Sat    D     1              3.07
# 92         5.75   1.00   F    Yes   Fri    D     2              2.88
# 111        7.25   1.00   F     No   Sat    D     1              7.25
# 172        7.25   5.15   M    Yes   Sun    D     2              3.62
# 149        7.51   2.00   M     No  Thur    L     2              3.76
# ..          ...    ...  ..    ...   ...  ...   ...               ...
# 182       45.35   3.50   M    Yes   Sun    D     3             15.12
# 156       48.17   5.00   M     No   Sun    D     6              8.03
# 59        48.27   6.73   M     No   Sat    D     4             12.07
# 212       48.33   9.00   M     No   Sat    D     4             12.08
# 170       50.81  10.00   M    Yes   Sat    D     3             16.94
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
df.nsmallest(10,'total_bill')
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 67         3.07  1.00   F    Yes   Sat    D     1              3.07
# 92         5.75  1.00   F    Yes   Fri    D     2              2.88
# 111        7.25  1.00   F     No   Sat    D     1              7.25
# 172        7.25  5.15   M    Yes   Sun    D     2              3.62
# 149        7.51  2.00   M     No  Thur    L     2              3.76
# 195        7.56  1.44   M     No  Thur    L     2              3.78
# 218        7.74  1.44   M    Yes   Sat    D     2              3.87
# 145        8.35  1.50   F     No  Thur    L     2              4.18
# 135        8.51  1.25   F     No  Thur    L     2              4.26
# 126        8.52  1.48   M     No  Thur    L     2              4.26
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# 92      Leah Ramirez  3508911676966392    Fri3780
# 111      Terri Jones  3559221007826887    Sat4801
# ...
