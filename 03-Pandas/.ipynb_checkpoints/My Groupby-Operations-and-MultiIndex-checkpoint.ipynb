# %% [markdown]
# # Groupby Operations and Multi-level Index

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data

# %%
df=pd.read_csv('mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## groupby() method

# %%
df.groupby('cylinders')

# %%
df.groupby('cylinders').mean()
# Out:
#                  mpg  displacement       weight  acceleration  model_year  \
# cylinders
# 3          20.550000     72.500000  2398.500000     13.250000   75.500000
# 4          29.286765    109.796569  2308.127451     16.601471   77.073529
# 5          27.366667    145.000000  3103.333333     18.633333   79.000000
# 6          19.985714    218.142857  3198.226190     16.263095   75.928571
# 8          14.963107    345.009709  4114.718447     12.955340   73.902913
#
#              origin
# cylinders
# 3          3.000000
# 4          1.985294
# 5          2.000000
# 6          1.190476
# 8          1.000000

# %%
df.groupby('cylinders').mean().index
# Out:
# Int64Index([3, 4, 5, 6, 8], dtype='int64', name='cylinders')

# %%
df.groupby('cylinders').mean().columns
# Out:
# Index(['mpg', 'displacement', 'weight', 'acceleration', 'model_year',
#        'origin'],
#       dtype='object')

# %%
df.groupby('cylinders').mean()['displacement']
# Out:
# cylinders
# 3     72.500000
# 4    109.796569
# 5    145.000000
# 6    218.142857
# 8    345.009709
# Name: displacement, dtype: float64

# %%
df.groupby('cylinders').mean().describe()
# Out:
#              mpg  displacement       weight  acceleration  model_year  \
# count   5.000000      5.000000     5.000000      5.000000    5.000000
# mean   22.430450    178.089827  3024.581084     15.540648   76.281003
# std     5.844855    107.673824   729.732372      2.405352    1.898060
# min    14.963107     72.500000  2308.127451     12.955340   73.902913
# 25%    19.985714    109.796569  2398.500000     13.250000   75.500000
# 50%    20.550000    145.000000  3103.333333     16.263095   75.928571
# 75%    27.366667    218.142857  3198.226190     16.601471   77.073529
# max    29.286765    345.009709  4114.718447     18.633333   79.000000
#
#          origin
# count  5.000000
# mean   1.835154
# std    0.793674
# min    1.000000
# 25%    1.190476
# 50%    1.985294
# 75%    2.000000
# max    3.000000

# %%
df.groupby('cylinders').describe()
# Out:
#              mpg                                                        \
#            count       mean       std   min    25%    50%    75%   max
# cylinders
# 3            4.0  20.550000  2.564501  18.0  18.75  20.25  22.05  23.7
# 4          204.0  29.286765  5.710156  18.0  25.00  28.25  33.00  46.6
# 5            3.0  27.366667  8.228204  20.3  22.85  25.40  30.90  36.4
# 6           84.0  19.985714  3.807322  15.0  18.00  19.00  21.00  38.0
# 8          103.0  14.963107  2.836284   9.0  13.00  14.00  16.00  26.6
#
#           displacement              ... model_year       origin            \
#                  count        mean  ...        75%   max  count      mean
# cylinders                           ...
# 3                  4.0   72.500000  ...      77.75  80.0    4.0  3.000000
# 4                204.0  109.796569  ...      80.00  82.0  204.0  1.985294
# 5                  3.0  145.000000  ...      79.50  80.0    3.0  2.000000
# ...

# %%
df.groupby('cylinders').describe().transpose()
# Out:
# cylinders                     3            4            5            6  \
# mpg          count     4.000000   204.000000     3.000000    84.000000
#              mean     20.550000    29.286765    27.366667    19.985714
#              std       2.564501     5.710156     8.228204     3.807322
#              min      18.000000    18.000000    20.300000    15.000000
#              25%      18.750000    25.000000    22.850000    18.000000
#              50%      20.250000    28.250000    25.400000    19.000000
#              75%      22.050000    33.000000    30.900000    21.000000
#              max      23.700000    46.600000    36.400000    38.000000
# displacement count     4.000000   204.000000     3.000000    84.000000
#              mean     72.500000   109.796569   145.000000   218.142857
#              std       5.000000    21.512147    33.286634    32.293512
#              min      70.000000    68.000000   121.000000   145.000000
# ...

# %% [markdown]
# ## Groupby Multiple Columns

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.groupby(['cylinders','model_year']).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
df.groupby(['cylinders','model_year']).mean().index
# Out:
# MultiIndex([(3, 72),
#             (3, 73),
#             (3, 77),
#             (3, 80),
#             (4, 70),
#             (4, 71),
#             (4, 72),
#             (4, 73),
#             (4, 74),
#             (4, 75),
#             (4, 76),
#             (4, 77),
#             (4, 78),
#             (4, 79),
#             (4, 80),
#             (4, 81),
#             (4, 82),
#             (5, 78),
#             (5, 79),
#             (5, 80),
#             (6, 70),
#             (6, 71),
#             (6, 73),
#             (6, 74),
#             (6, 75),
#             (6, 76),
#             (6, 77),
#             (6, 78),
#             (6, 79),
#             (6, 80),
#             (6, 81),
#             (6, 82),
#             (8, 70),
#             (8, 71),
#             (8, 72),
#             (8, 73),
#             (8, 74),
#             (8, 75),
#             (8, 76),
#             (8, 77),
#             (8, 78),
#             (8, 79),
#             (8, 81)],
# ...

# %% [markdown]
# # MultiIndex
# ## The MultiIndex Object

# %%
df.groupby(['cylinders','model_year']).mean().index.levels
# Out:
# FrozenList([[3, 4, 5, 6, 8], [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82]])

# %%
df.groupby(['cylinders','model_year']).mean().index.names
# Out:
# FrozenList(['cylinders', 'model_year'])

# %% [markdown]
# # Indexing with the Hierarchial Index

# %%
df.groupby(['cylinders','model_year']).mean().head()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000          70.0  2330.000000          13.5
#           73          18.000000          70.0  2124.000000          13.5
#           77          21.500000          80.0  2720.000000          13.5
#           80          23.700000          70.0  2420.000000          12.5
# 4         70          25.285714         107.0  2292.571429          16.0
#
#                         origin
# cylinders model_year
# 3         72          3.000000
#           73          3.000000
#           77          3.000000
#           80          3.000000
# 4         70          2.285714

# %% [markdown]
# ## Grab Based on Outside Index

# %%
df.groupby(['cylinders','model_year']).mean().loc[8]
# Out:
#                   mpg  displacement       weight  acceleration  origin
# model_year
# 70          14.111111    367.555556  3940.055556     11.194444     1.0
# 71          13.428571    371.714286  4537.714286     12.214286     1.0
# 72          13.615385    344.846154  4228.384615     13.000000     1.0
# 73          13.200000    365.250000  4279.050000     12.250000     1.0
# 74          14.200000    315.200000  4438.400000     14.700000     1.0
# 75          15.666667    330.500000  4108.833333     13.166667     1.0
# 76          14.666667    324.000000  4064.666667     13.222222     1.0
# 77          16.000000    335.750000  4177.500000     13.662500     1.0
# 78          19.050000    300.833333  3563.333333     13.266667     1.0
# 79          18.630000    321.400000  3862.900000     15.400000     1.0
# 81          26.600000    350.000000  3725.000000     19.000000     1.0

# %%
df.groupby(['cylinders','model_year']).mean().loc[[6,8]]
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 6         70          20.500000    199.000000  2710.500000     15.500000
#           71          18.000000    243.375000  3171.875000     14.750000
#           73          19.000000    212.250000  2917.125000     15.687500
#           74          17.857143    230.428571  3320.000000     16.857143
#           75          17.583333    233.750000  3398.333333     17.708333
#           76          20.000000    221.400000  3349.600000     17.000000
#           77          19.500000    220.400000  3383.000000     16.900000
#           78          19.066667    213.250000  3314.166667     16.391667
#           79          22.950000    205.666667  3025.833333     15.433333
#           80          25.900000    196.500000  3145.500000     15.050000
#           81          23.428571    184.000000  3093.571429     15.442857
# ...

# %%
df.groupby(['cylinders','model_year']).mean().loc[(8,78)]
# Out:
# mpg               19.050000
# displacement     300.833333
# weight          3563.333333
# acceleration      13.266667
# origin             1.000000
# Name: (8, 78), dtype: float64

# %% [markdown]
# # Grab Based on Cross-section with .xs()

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df=df.groupby(['cylinders','model_year']).mean()

# %%
df
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
df.groupby(['cylinders','model_year']).mean().loc[8]
# Out:
#                   mpg  displacement       weight  acceleration  origin
# model_year
# 70          14.111111    367.555556  3940.055556     11.194444     1.0
# 71          13.428571    371.714286  4537.714286     12.214286     1.0
# 72          13.615385    344.846154  4228.384615     13.000000     1.0
# 73          13.200000    365.250000  4279.050000     12.250000     1.0
# 74          14.200000    315.200000  4438.400000     14.700000     1.0
# 75          15.666667    330.500000  4108.833333     13.166667     1.0
# 76          14.666667    324.000000  4064.666667     13.222222     1.0
# 77          16.000000    335.750000  4177.500000     13.662500     1.0
# 78          19.050000    300.833333  3563.333333     13.266667     1.0
# 79          18.630000    321.400000  3862.900000     15.400000     1.0
# 81          26.600000    350.000000  3725.000000     19.000000     1.0

# %%
df.xs(key=8,axis=0,level='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration  origin
# model_year
# 70          14.111111    367.555556  3940.055556     11.194444     1.0
# 71          13.428571    371.714286  4537.714286     12.214286     1.0
# 72          13.615385    344.846154  4228.384615     13.000000     1.0
# 73          13.200000    365.250000  4279.050000     12.250000     1.0
# 74          14.200000    315.200000  4438.400000     14.700000     1.0
# 75          15.666667    330.500000  4108.833333     13.166667     1.0
# 76          14.666667    324.000000  4064.666667     13.222222     1.0
# 77          16.000000    335.750000  4177.500000     13.662500     1.0
# 78          19.050000    300.833333  3563.333333     13.266667     1.0
# 79          18.630000    321.400000  3862.900000     15.400000     1.0
# 81          26.600000    350.000000  3725.000000     19.000000     1.0

# %%
df[df['model_year'].isin([70,72,74,76,78,80])].groupby(['cylinders','model_year']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'model_year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e7f7197660ee> in <module>
# ...

# %%
df[df['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cylinders'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-6260af172795> in <module>
# ...

# %%
df
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %% [markdown]
# ## Swap levels

# %%
df=df.swaplevel()

# %%
df
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
df[df['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cylinders'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-6260af172795> in <module>
# ...

# %%
df
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %% [markdown]
# ## Sorting MultiIndex

# %%
df.sort_index(level='cylinders',ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 8         81          26.600000    350.000000  3725.000000     19.000000
#           79          18.630000    321.400000  3862.900000     15.400000
#           78          19.050000    300.833333  3563.333333     13.266667
#           77          16.000000    335.750000  4177.500000     13.662500
#           76          14.666667    324.000000  4064.666667     13.222222
#           75          15.666667    330.500000  4108.833333     13.166667
#           74          14.200000    315.200000  4438.400000     14.700000
#           73          13.200000    365.250000  4279.050000     12.250000
#           72          13.615385    344.846154  4228.384615     13.000000
#           71          13.428571    371.714286  4537.714286     12.214286
#           70          14.111111    367.555556  3940.055556     11.194444
# ...

# %%
df.sort_index(level='model_year',ascending=True)
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 4         70          25.285714    107.000000  2292.571429     16.000000
# 6         70          20.500000    199.000000  2710.500000     15.500000
# 8         70          14.111111    367.555556  3940.055556     11.194444
# 4         71          27.461538    101.846154  2056.384615     16.961538
# 6         71          18.000000    243.375000  3171.875000     14.750000
# 8         71          13.428571    371.714286  4537.714286     12.214286
# 3         72          19.000000     70.000000  2330.000000     13.500000
# 4         72          23.428571    111.535714  2382.642857     17.214286
# 8         72          13.615385    344.846154  4228.384615     13.000000
# 3         73          18.000000     70.000000  2124.000000     13.500000
# 4         73          22.727273    109.272727  2338.090909     17.136364
# ...

# %% [markdown]
# # Advanced: agg() method

# %%
df=pd.read_csv('mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.agg(['max','mean'])
# Out:
#             mpg  cylinders  displacement horsepower       weight  \
# max   46.600000   8.000000    455.000000          ?  5140.000000
# mean  23.514573   5.454774    193.425879        NaN  2970.424623
#
#       acceleration  model_year    origin              name
# max       24.80000    82.00000  3.000000  vw rabbit custom
# mean      15.56809    76.01005  1.572864               NaN

# %% [markdown]
# ### Specify aggregate methods per column

# %%
df.agg({'mpg':['std','mean'],'displacement':['min','max','mean']})
# Out:
#             mpg  displacement
# std    7.815984           NaN
# mean  23.514573    193.425879
# min         NaN     68.000000
# max         NaN    455.000000

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.groupby('cylinders').agg({'mpg':['std','mean'],'displacement':['min','max','mean']})
# Out:
#                 mpg            displacement
#                 std       mean          min    max        mean
# cylinders
# 3          2.564501  20.550000         70.0   80.0   72.500000
# 4          5.710156  29.286765         68.0  156.0  109.796569
# 5          8.228204  27.366667        121.0  183.0  145.000000
# 6          3.807322  19.985714        145.0  262.0  218.142857
# 8          2.836284  14.963107        260.0  455.0  345.009709
