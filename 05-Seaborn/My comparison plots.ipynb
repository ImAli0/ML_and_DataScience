# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
sns.jointplot(data=df,x='reading score',y='math score')

# %%
sns.jointplot(data=df,x='reading score',y='math score',kind='hex')

# %%
sns.jointplot(data=df,x='reading score',y='math score',kind='hist')

# %%
sns.jointplot(data=df,x='reading score',y='math score',kind='kde')

# %%
sns.jointplot(data=df,x='reading score',y='math score',kind='kde',shade=True)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='gender')

# %%
sns.pairplot(df,hue='gender',palette='viridis')

# %%
sns.pairplot(df,hue='gender',palette='BuPu')

# %%
sns.pairplot(df,hue='gender',palette='Wistia')

# %%
sns.pairplot(df,hue='gender',palette='summer')

# %%
sns.pairplot(df,hue='gender',palette='terrain_r')

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True)

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True,diag_kind='hist')
