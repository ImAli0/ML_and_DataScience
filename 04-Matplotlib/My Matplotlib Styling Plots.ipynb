# %% [markdown]
# # Matplotlib Styling

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### The Data

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=x**3

# %% [markdown]
# ## Legends
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,2,2])

ax.plot(x,y, label='y=x^3')
ax.plot(x,x**4, label='x^4')
ax.plot(x,x**(7/2),label='x^(7/2)')
ax.legend()

# %% [markdown]
# Notice how legend could potentially overlap some of the actual plot!
#
# The **legend** function takes an optional keyword argument **loc** that can be used to specify where in the figure the legend is to be drawn. The allowed values of **loc** are numerical codes for the various places the legend can be drawn. See the [documentation page](http://matplotlib.org/users/legend_guide.html#legend-location) for details. Some of the most common **loc** values are:

# %%
ax.legend(loc=4)
fig

# %%
ax.legend(loc=(1.002,0))
fig

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# ### Colors with MatLab like syntax
#
# With matplotlib, we can define the colors of lines and other graphical elements in a number of ways. First of all, we can use the MATLAB-like syntax where `'b'` means blue, `'g'` means green, etc. The MATLAB API for selecting line styles are also supported: where, for example, 'b.-' means a blue line with dots:

# %%
## MATLAB style line color and style
fig, ax=plt.subplots()
ax.plot(x,x**4, 'r--.')
ax.plot(x,x**5, 'b--.')

# %% [markdown]
# ## Suggested Approach: Use keyword arguments
#
# ### Colors with the color parameter

# %% [markdown]
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the `color` and `alpha` keyword arguments. Alpha indicates opacity.

# %%
fig, ax=plt.subplots()

ax.plot(x,x+1, color='brown', alpha=1)
ax.plot(x,x**2, color='#500041') # RGB hex code
ax.plot(x,x**0.9, color='#bada55')
ax.plot(x,x**2.2, color='#0f3d4f')

# %% [markdown]
# ## Line and marker styles
#
# ## Linewidths
#
# To change the line width, we can use the `linewidth` or `lw` keyword argument.

# %%
fig, ax=plt.subplots(figsize=(10,5))

ax.plot(x,x, color='black', linewidth=0.25)
ax.plot(x,x**2, color='darkgreen', lw=0.5)
ax.plot(x,x*4,color='#0F3D4F',lw=2)
ax.plot(x,x*38,color='#1d9D8A',lw=9)

# %% [markdown]
# ## Linestyles

# %%
# possible linestype options ‘--‘, ‘–’, ‘-.’, ‘:’, ‘steps’
fig,ax=plt.subplots(figsize=(10,6))

ax.plot(x,x, color='black', linewidth=3,linestyle='-')
ax.plot(x,x**2, color='darkgreen', lw=5,ls='-.')
ax.plot(x,x*4,color='#0F3D4F',lw=2,ls='--')
ax.plot(x,x*38,color='#1d9D8A',lw=9,ls=':')

# %% [markdown]
# ### Custom linestyle dash
#
# The dash sequence is a sequence of floats of even length describing
# the length of dashes and spaces in points.
#
# For example, (5, 2, 1, 2) describes a sequence of 5 point and 1 point
# dashes separated by 2 point spaces.
#
# First, we see we can actually "grab" the line from the .plot() command

# %%
fig, ax=plt.subplots(figsize=(10,5))

lines=ax.plot(x,x)

print(type(lines))
# Out:
# <class 'list'>

# %%
fig, ax=plt.subplots(figsize=(10,5))

lines=ax.plot(x,x*8, color='violet', lw=6)
lines[0].set_dashes([4.3,2,4,5,3])

# %% [markdown]
# ## Markers
#
# ### Markers Style

# %%
fig,ax=plt.subplots(figsize=(10,6))

ax.plot(x,x, color='black', linewidth=3,linestyle='-',marker='h',markersize=
       8)
ax.plot(x,x**2, color='darkgreen', lw=5,ls='-.', marker='d',ms=15)
ax.plot(x,x*4,color='#0F3D4F',lw=2,ls='--', marker='x', markersize=10)
ax.plot(x,x*38,color='#1d9D8A',lw=9,ls=':',marker='8', ms=14)

# %% [markdown]
# ## Custom marker edges, thickness, size, and style

# %%
fig,ax=plt.subplots(figsize=(10,6))

ax.plot(x,x, color='black', linewidth=3,linestyle='-',marker='h',markersize=
       8,markerfacecolor='red',markeredgewidth=2,markeredgecolor='blue')
ax.plot(x,x**2, color='darkgreen', lw=5,ls='-.', marker='d',ms=15,mfc=
       'orange',mew=3,mec='brown')
ax.plot(x,x*4,color='#0F3D4F',lw=2,ls='--', marker='x', markersize=10,mfc=
       'violet',mew=1,mec='black')
ax.plot(x,x*38,color='#1d9D8A',lw=9,ls=':',marker='8', ms=14,mfc='purple',
       mew=2,mec='brown')
